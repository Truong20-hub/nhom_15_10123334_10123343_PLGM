# %% [markdown]
# # ⚙️ GIAI ĐOẠN 2: TIỀN XỬ LÝ DỮ LIỆU & THIẾT KẾ PIPELINE
# **Mục tiêu:**
# 1. Phân chia Train/Test phân tầng (Stratified Split 80/20) để tránh rò rỉ dữ liệu (Data Leakage).
# 2. Xây dựng Scikit-Learn `Pipeline` và `StandardScaler`.
# 3. Xuất `schema.json` định nghĩa chuẩn cho Backend và Frontend.

# %%
import os
import sys
import json
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

sys.path.append('../src')
from preprocess import FEATURE_COLUMNS, LABEL_MAPPING, get_schema, save_schema, prepare_train_test

# %%
# Phân chia dữ liệu train/test có bảo toàn tỷ lệ lớp
X_train, X_test, y_train, y_test = prepare_train_test('../data/train.csv', test_size=0.2, random_state=42)
print(f'Kích thước X_train: {X_train.shape}')
print(f'Kích thước X_test:  {X_test.shape}')
print('Tỷ lệ các lớp trên tập Train:')
print(y_train.value_counts(normalize=True))

# %%
# Xuất schema.json
schema = save_schema('../models/schema.json')
print('Schema đã lưu thành công. Ví dụ đặc trưng ram:')
print(json.dumps(schema['features']['ram'], indent=2, ensure_ascii=False))
