# %% [markdown]
# # 🧠 GIAI ĐOẠN 3: HUẤN LUYỆN VÀ TINH CHỈNH ≥4 MÔ HÌNH HỌC MÁY
# **Các mô hình thử nghiệm:**
# 1. Logistic Regression (Baseline tuyến tính chuẩn hóa)
# 2. Support Vector Machine (SVC Linear kernel)
# 3. Random Forest (Mô hình cây tích hợp Bagging)
# 4. Gradient Boosting (Mô hình chuỗi tăng cường Boosting)
#
# Phương pháp: 5-Fold Stratified Cross-Validation + GridSearchCV.

# %%
import sys
sys.path.append('../src')
from train import train_and_evaluate_all

# Chạy toàn bộ quá trình huấn luyện và tối ưu
best_name, best_pipe, metadata = train_and_evaluate_all()

# %%
# Hiển thị siêu tham số của mô hình tối ưu nhất
print(f'Mô hình chiến thắng: {best_name}')
print('Pipeline structure:')
print(best_pipe)
